# %% [markdown]
# # 🏛️ HMO Auditor - Manual de Desarrollo Maestro (Edición Elite)
#
# ## 📖 Introducción y Evolución del Proyecto
# Este documento es un registro vivo de la ingeniería detrás del ecosistema **HMO Auditor**. No solo explica el código, sino la **justificación técnica** y el paso a paso de por qué elegimos cada tecnología.
#
# ### 📍 El Inicio: La Necesidad de Blindaje
# El proyecto nació de la necesidad de automatizar auditorías ISO y académicas sin comprometer el secreto profesional. Mientras el mundo se movía a la nube, nosotros decidimos mover la IA a la **oficina del auditor**.
#
# ---

# %% [markdown]
# ## 🛠️ Arquitectura Core: ¿Por qué Local RAG?
#
# ### 1. Ollama + Llama 3
# Elegimos **Ollama** porque permite la ejecución de modelos de lenguaje potentes (7B+) en hardware estándar.
#
# ### 2. ChromaDB (Vector Store)
# Utilizamos **ChromaDB** para la persistencia vectorial. Es el motor que permite que el sistema "recuerde" las normas y las evidencias de la empresa sin subirlas a Internet.
#
# ---

# %%
# Justificación Técnica: Verificación de Dependencias Críticas
import streamlit as st
import chromadb
import pandas as pd

print("✅ Entorno técnico validado para Auditoría RAG.")

# %% [markdown]
# ## 🚀 Evolución del Código (Logros Técnicos)
#
# ### Paso 1: Generadores Legales
# Creamos scripts en `python-docx` y `openpyxl` diseñados para inyectar cabeceras profesionales y firmas de integridad.
#
# ### Paso 2: El Dashboard Multi-Sesión (V1.3)
# Implementamos un sistema de persistencia basado en JSON y organización de carpetas corporativa.
#
# ---

# %% [markdown]
# ## 🔒 Seguridad e Integridad
# Cada documento generado es sellado con un hash **SHA-256**. Esto permite que en una auditoría externa, se pueda verificar que el archivo no ha sido modificado desde su creación por la IA.
#
# ---

# %% [markdown]
# ## 🎯 Conclusión y Visión de Futuro
# HMO Auditor está diseñado para escalar. Su arquitectura modular permite añadir nuevas normas simplemente inyectando el PDF en el motor vectorial.
#
# **Desarrollado para:** SENA - HMO Auditor Project
